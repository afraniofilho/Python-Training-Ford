# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/Python-Training-Ford/blob/main/Aula_09_Ford.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('MICRODADOS_ENEM_2018_resumo2.csv')

# %%
df.shape
# Out:
# (500000, 6)

# %%
df.head()
# Out:
#    Unnamed: 0  NU_IDADE  TP_COR_RACA Q006  NU_NOTA_MT TP_SEXO
# 0           0      44.0            1    A         NaN       M
# 1           1      23.0            3    B       480.3       F
# 2           2      23.0            1    C         NaN       F
# 3           3      26.0            3    B         NaN       F
# 4           4      20.0            0    B         NaN       M

# %%
df['NU_IDADE'].isna().sum()
# Out:
# 7

# %%
df['NU_IDADE'].count()
# Out:
# 499993

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# NU_IDADE            7
# TP_COR_RACA         0
# Q006                0
# NU_NOTA_MT     128764
# TP_SEXO             0
# dtype: int64

# %%
df.dropna(subset=['NU_IDADE'], inplace=True)

# %%
df['NU_IDADE'].isna().sum()
# Out:
# 0

# %%
#Qual a médias das idades dos participantes?

# %%
df['NU_IDADE'].mean()
# Out:
# 22.46914056796795

# %%
print('A idade média dos participantes é {:.2f} anos'.format(df['NU_IDADE'].mean()))
# Out:
# A idade média dos participantes é 22.47 anos

# %%
#Qual o percentual de homens e mulheres no exame?

# %%
genero = df.TP_SEXO.value_counts(normalize=True)

# %%
genero
# Out:
# F    0.644216
# M    0.355784
# Name: TP_SEXO, dtype: float64

# %%
type(genero)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(x=genero, labels=['Feminino','Masculino'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9923ee38d0>,
# ...
#  [Text(-0.48148933011161066, 0.989023773722691, 'Feminino'),
#   Text(0.4814893301116101, -0.9890237737226912, 'Masculino')])

# %%
plt.pie(x=genero, labels=['Feminino','Masculino'], shadow = True, colors=['#4177A3','#F0CC95'], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9923706a10>,
# ...
#  [Text(-0.48149858999936695, 0.9890192656508879, 'Feminino'),
#   Text(0.48149858999936684, -0.989019265650888, 'Masculino')],
#  [Text(-0.2626355945451092, 0.5394650539913933, '64.42%'),
#   Text(0.26263559454510915, -0.5394650539913934, '35.58%')])

# %%
import seaborn as sns

# %%
sns.scatterplot(x='NU_IDADE', y='NU_NOTA_MT', data=df)

# %%
df_nota_matematica = df.loc[df.NU_NOTA_MT > 0]

# %%
sns.scatterplot(x='NU_IDADE', y='NU_NOTA_MT', data=df_nota_matematica)
